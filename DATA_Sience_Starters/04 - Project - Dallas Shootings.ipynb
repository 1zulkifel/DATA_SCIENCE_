# %% [markdown]
# ![Data Science Workflow](files/kifel.jpeg)
# <table><tr>
# <td> <img src="files/DSworkflow.png" alt="Drawing" style="width: 700px;"/> </td>
# <td> <img src="files/images.png" alt="Drawing" style="width: 400px;"/> </td>
# </tr></table>

# %% [markdown]
# # Project - Dallas Shootings

# %% [markdown]
# <table><tr>
# <td> <img src="files/kifel.jpeg" alt="Drawing" style="width: 250px;"/> </td>
# <td> <img src="DSworkflow.png" alt="Drawing" style="width: 600px;"/> </td>
# </tr></table>

# %% [markdown]
# ## Goal of Project
# - A newspaper want a visualization of the shootings in Dallas with focus on subjects
# - We will read data from from database and join into broader datasets
# - We will explore ideas to visualize it and create a map with the shootings

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 1.b: Connect to SQLite database
# - Use `sqlite3.connect(<filename>)` to connect to the database `files/dallas-ois.sqlite`

# %%
conn=sqlite3.connect('dallas-ois.sqlite')

# %%
cursor=conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name");

# %% [markdown]
# ### Step 1. c: Read data into DataFrames
# - The database consists of 3 tables: `incident`, `officers`, `subjects`
# - Read the data from each table into a DataFrame.
# - HINT: Use `pandas` `read_sql(sql_stmt, conn)`, which takes the SQL statement (`sql_stmt`) and the data base connection `conn` from previous step.
# - HINT: The structure of the SQL statement is as follows.
# ```SQL
# SELECT * FROM table
# ```

# %%
cursor.fetchall()
# Out:
# [('incidents',), ('officers',), ('subjects',)]

# %%
incidents=pd.read_sql("select * from incidents",conn);
incidents.head(2)
# Out:
#   case_number        date                  location subject_statuses  \
# 0      44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1     121982X  2010-05-03  1300 N. Munger Boulevard          Injured
#
#   subject_weapon             subjects  subject_count  \
# 0        Handgun     Curry, James L/M              1
# 1        Handgun  Chavez, Gabriel L/M              1
#
#                                     officers  officer_count  \
# 0  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1                       Padilla, Gilbert L/M              1
#
#   grand_jury_disposition attorney_general_forms_url  \
# 0                No Bill                       None
# 1                No Bill                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text  latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...       NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...       NaN        NaN

# %%
subjects=pd.read_sql("select * from subjects",conn);
subjects.head(2)
# Out:
#   case_number race gender last_name first_name        full_name
# 0      44523A    L      M     Curry      James     Curry, James
# 1     121982X    L      M    Chavez    Gabriel  Chavez, Gabriel

# %%
officers=pd.read_sql("select * from officers",conn);
officers.head(2)
# Out:
#   case_number race gender  last_name first_name         full_name
# 0      44523A    L      M     Patino    Michael   Patino, Michael
# 1      44523A    W      M  Fillingim      Brian  Fillingim, Brian

# %% [markdown]
# ### Step 1.d: Explore the length of the DataFrames
# - What is the length of the DataFrames
#     - HINT: Apply `len(...)` on the DataFrames
# - We want to explore data based on officers and data based on subjects, both with incident data.
# - Notice: It is difficult to create one dataset for both problems
# - Explore data further to understand why

# %%
len(officers),len(incidents),len(subjects)
# Out:
# (370, 219, 223)

# %% [markdown]
# ### Step 1.e: Read data into dataset
# - Create first dataset `subject_incidents` as officers joined with incidents.
#     - What does this dataset give us?
#     - HINT:
#     ```SQL
#     SELECT * FROM table_1 JOIN table_2 ON table_1.column_name_1=table_2.column_name_2
#     ```
#     - HINT: You can join on columns `case_number`
# - Is all data represented?

# %%
subject_incidents=pd.read_sql("select * from subjects join incidents on subjects.case_number=incidents.case_number ",conn)

# %%
subject_incidents.head()
# Out:
#   case_number race gender last_name first_name        full_name case_number  \
# 0      44523A    L      M     Curry      James     Curry, James      44523A
# 1     121982X    L      M    Chavez    Gabriel  Chavez, Gabriel     121982X
# 2     605484T    L      M   Salinas       Nick    Salinas, Nick     605484T
# 3     384832T    B      M     Smith      James     Smith, James     384832T
# 4     384832T    B      M      Dews    Antonio    Dews, Antonio     384832T
#
#          date                  location subject_statuses  ...  \
# 0  2013-02-23     3000 Chihuahua Street          Injured  ...
# 1  2010-05-03  1300 N. Munger Boulevard          Injured  ...
# 2  2007-08-12   200 S. Stemmons Freeway            Other  ...
# 3  2007-05-26           7900 S. Loop 12   Shoot and Miss  ...
# 4  2007-05-26           7900 S. Loop 12   Shoot and Miss  ...
#
#                                             subjects subject_count  \
# 0                                   Curry, James L/M             1
# 1                                Chavez, Gabriel L/M             1
# 2                                  Salinas, Nick L/M             1
# 3  Smith, James B/M; Dews, Antonio B/M; Spearman,...             3
# 4  Smith, James B/M; Dews, Antonio B/M; Spearman,...             3
#
#                                     officers officer_count  \
# 0  Patino, Michael L/M; Fillingim, Brian W/M             2
# 1                       Padilla, Gilbert L/M             1
# 2                          Poston, Jerry W/M             1
# 3                         Mondy, Michael B/M             1
# 4                         Mondy, Michael B/M             1
#
#    grand_jury_disposition attorney_general_forms_url  \
# 0                 No Bill                       None
# 1                 No Bill                       None
# 2             See Summary                       None
# 3                    None                       None
# 4                    None                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...      NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...      NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...      NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
# 4  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - A step to get to understand the data better is to explore the data types
# - Get the data types by `.dtypes`

# %%
subject_incidents.dtypes
# Out:
# case_number                    object
# race                           object
# gender                         object
# last_name                      object
# first_name                     object
# full_name                      object
# case_number                    object
# date                           object
# location                       object
# subject_statuses               object
# subject_weapon                 object
# subjects                       object
# subject_count                   int64
# officers                       object
# officer_count                   int64
# grand_jury_disposition         object
# attorney_general_forms_url     object
# summary_url                    object
# summary_text                   object
# latitude                      float64
# longitude                     float64
# dtype: object

# %% [markdown]
# ### Step 2.b: Check for null (missing) values
# - Data often is missing entries - there can be many reasons for this
# - We need to deal with that (will do later in course)
# - Use ```.isna().sum()```

# %%
subject_incidents.isna().sum()
# Out:
# case_number                     0
# race                            0
# gender                          0
# last_name                       0
# first_name                     18
# full_name                       0
# case_number                     0
# date                            0
# location                        0
# subject_statuses                0
# subject_weapon                  0
# subjects                        0
# subject_count                   0
# officers                        0
# officer_count                   0
# grand_jury_disposition         88
# attorney_general_forms_url    221
# summary_url                     3
# summary_text                    3
# latitude                        9
# longitude                       9
# dtype: int64

# %% [markdown]
# ### Step 2.c: Explore subject_statuses column
# - As part of finding useful features let's explore `subject_statuses`
# - We know that `subject_statuses` is categorical.
# - Therefore we can use `groupby(...)` and `count()`

# %%
subject_incidents.groupby('subject_statuses').count()
# Out:
#                       case_number  race  gender  last_name  first_name  \
# subject_statuses
# 1 Deceased 1 Injured            2     2       2          2           2
# 2 Injured                       1     1       1          1           1
# Deceased                       69    69      69         69          67
# Deceased Injured                2     2       2          2           2
# Injured                        60    60      60         60          60
# Other                           2     2       2          2           2
# Shoot and Miss                 87    87      87         87          71
#
#                       full_name  case_number  date  location  subject_weapon  \
# subject_statuses
# 1 Deceased 1 Injured          2            2     2         2               2
# 2 Injured                     1            1     1         1               1
# Deceased                     69           69    69        69              69
# Deceased Injured              2            2     2         2               2
# Injured                      60           60    60        60              60
# Other                         2            2     2         2               2
# Shoot and Miss               87           87    87        87              87
#
#                       subjects  subject_count  officers  officer_count  \
# subject_statuses
# 1 Deceased 1 Injured         2              2         2              2
# 2 Injured                    1              1         1              1
# Deceased                    69             69        69             69
# Deceased Injured             2              2         2              2
# Injured                     60             60        60             60
# Other                        2              2         2              2
# Shoot and Miss              87             87        87             87
#
#                       grand_jury_disposition  attorney_general_forms_url  \
# subject_statuses
# 1 Deceased 1 Injured                       2                           0
# 2 Injured                                  1                           0
# Deceased                                  67                           1
# Deceased Injured                           2                           0
# Injured                                   58                           1
# Other                                      1                           0
# Shoot and Miss                             4                           0
#
#                       summary_url  summary_text  latitude  longitude
# subject_statuses
# 1 Deceased 1 Injured            2             2         2          2
# 2 Injured                       1             1         1          1
# Deceased                       67            67        68         68
# Deceased Injured                2             2         2          2
# Injured                        60            60        57         57
# Other                           2             2         1          1
# Shoot and Miss                 86            86        83         83

# %% [markdown]
# ### Step 2.d: Explore race column
# - Repeat of previous step on column `race`

# %%
subject_incidents.groupby('race').count()
# Out:
#       case_number  gender  last_name  first_name  full_name  case_number  \
# race
# A               2       2          2           2          2            2
# B             111     111        111         104        111          111
# L              72      72         72          61         72           72
# W              38      38         38          38         38           38
#
#       date  location  subject_statuses  subject_weapon  subjects  \
# race
# A        2         2                 2               2         2
# B      111       111               111             111       111
# L       72        72                72              72        72
# W       38        38                38              38        38
#
#       subject_count  officers  officer_count  grand_jury_disposition  \
# race
# A                 2         2              2                       0
# B               111       111            111                      67
# L                72        72             72                      37
# W                38        38             38                      31
#
#       attorney_general_forms_url  summary_url  summary_text  latitude  \
# race
# A                              0            2             2         2
# B                              0          109           109       106
# L                              2           71            71        68
# W                              0           38            38        38
#
#       longitude
# race
# A             2
# B           106
# L            68
# W            38

# %% [markdown]
# ### Step 2.e: Explore more columns
# - Feel free to explore more columns (also called features)

# %%
subject_incidents.groupby('subject_weapon').count().head(3)
# Out:
#                 case_number  race  gender  last_name  first_name  full_name  \
# subject_weapon
# Assault Rifle             4     4       4          4           4          4
# BB Gun                    1     1       1          1           1          1
# BB Rifle                  3     3       3          3           3          3
#
#                 case_number  date  location  subject_statuses  subjects  \
# subject_weapon
# Assault Rifle             4     4         4                 4         4
# BB Gun                    1     1         1                 1         1
# BB Rifle                  3     3         3                 3         3
#
#                 subject_count  officers  officer_count  \
# subject_weapon
# Assault Rifle               4         4              4
# BB Gun                      1         1              1
# BB Rifle                    3         3              3
#
#                 grand_jury_disposition  attorney_general_forms_url  \
# subject_weapon
# Assault Rifle                        1                           0
# BB Gun                               0                           0
# BB Rifle                             3                           0
#
#                 summary_url  summary_text  latitude  longitude
# subject_weapon
# Assault Rifle             3             3         4          4
# BB Gun                    1             1         1          1
# BB Rifle                  3             3         3          3

# %%
subject_incidents['subject_weapon'].value_counts()
# Out:
# Handgun              98
# Vehicle              37
# Unarmed              33
# Knife                10
# Shotgun              10
# Hands                10
# Rifle                 4
# Assault Rifle         4
# BB Rifle              3
# Taser                 2
# Pellet Gun            2
# OC Spray              1
# Toy Rifle             1
# Paint Ball Rifle      1
# Simulated Handgun     1
# Toy Handgun           1
# Rock                  1
# Screwdriver           1
# BB Gun                1
# Box Cutter            1
# Toy Handun            1
# Name: subject_weapon, dtype: int64

# %% [markdown]
# ### Step 2.f: Visualize ideas
# - We want to make a visual plot of the shooting incident
# - Let's explore if we can make a plot based on longitude and latitude.
#     - HINT: use `plot.scatter(x='longitude', y='latitude')`
# - Then the analysis phase will focus on how to make useful insights with the feature selections.

# %%
subject_incidents.plot.scatter(x='longitude', y='latitude',color='c',alpha=0.50)

# %% [markdown]
# ## Step 3: Analyze
# - Feature selection
# - Model selection
# - Analyze data

# %% [markdown]
# ### Step 3.a: Feature selection
# - Here we will continue with the features selected feel free to explore other features.
# - Create a `dataset` with the features: `race`, `subject_statuses`, `latitude`, `longitude`
#     - HINT: Select the features of the DataFrame `subject_incidents` by filtering with a list of the columns.
# - To make further processing easier apply `dropna()` to remove missing data.

# %%
dataset=subject_incidents[['race', 'subject_statuses', 'latitude', 'longitude']].dropna()

# %%
len(dataset)
# Out:
# 214

# %%
dataset
# Out:
#     race subject_statuses  latitude  longitude
# 9      L         Deceased  32.68642 -96.908674
# 10     B         Deceased  32.86400 -96.898998
# 11     W   Shoot and Miss  32.81482 -96.826787
# 12     B          Injured  32.77540 -96.767489
# 13     B   Shoot and Miss  32.74417 -96.828470
# ..   ...              ...       ...        ...
# 218    B   Shoot and Miss  32.65628 -96.869793
# 219    B   Shoot and Miss  32.70483 -96.779494
# 220    L   Shoot and Miss  32.79473 -96.764017
# 221    B   Shoot and Miss  32.81664 -96.851409
# 222    B         Deceased  32.77945 -96.804915
#
# [214 rows x 4 columns]

# %% [markdown]
# ### Step 3.b: How to visualize features
# - We want to visualize the two features: `race` and `subject_statuses`
# - A way to visualize data is by color and size.
# - Idea:
#     - Map the race features to colors
#     - Map the subject_statuses to a size

# %% [markdown]
# ### Step 3.b.1: Convert column
# - The `race` column has the following categories: B, W, A, L
# - We can map that to color values ([docs](https://matplotlib.org/stable/gallery/color/named_colors.html))
# - A simple way to map columns is by using `apply` on a lambda-function.
#     - Create a dict with the mapping:
#     ```Python
# mapping = {'B': 'blue', 'W': 'yellow', 'A': 'red', 'L': 'cyan'}
# ```
#     - Do the mapping with `apply`and `lambda` as follows
#     ```Python
# dataset['race'] = dataset['race'].apply(lambda x: mapping[x])
# ```

# %%
dataset['race'].value_counts()
# Out:
# B    106
# L     68
# W     38
# A      2
# Name: race, dtype: int64

# %%
mapping = {'B': 'b', 'W': 'y', 'A': 'r', 'L': 'c'}
dataset['race'] = dataset['race'].apply(lambda x: mapping[x])

# %%
# Out:
#     race  subject_statuses  latitude  longitude
# 9      c              1000  32.68642 -96.908674
# 10     b              1000  32.86400 -96.898998
# 11     y               250  32.81482 -96.826787
# 12     b               500  32.77540 -96.767489
# 13     b               250  32.74417 -96.828470
# ..   ...               ...       ...        ...
# 218    b               250  32.65628 -96.869793
# 219    b               250  32.70483 -96.779494
# 220    c               250  32.79473 -96.764017
# 221    b               250  32.81664 -96.851409
# 222    b              1000  32.77945 -96.804915
#
# [214 rows x 4 columns]

# %% [markdown]
# ### Step 3.b.2: Convert column
# - The `subject_statuses` has the following categories: `'1 Deceased 1 Injured', '2 Injured', 'Deceased', 'Deceased Injured', 'Injured', 'Other', 'Shoot and Miss'`
# - The main categories are: `'Deceased', 'Injured', 'Shoot and Miss'`
# - A simple way is quite similar to last step.
#     - Create a mapping of the main categories:
#     ```Python
# mapping = {'Deceased': 1000, 'Injured': 500, 'Shoot and Miss': 250}
# ```
#     - Do the mapping with `apply`and `lambda` as follows
#     ```Python
# dataset['subject_statuses'] = dataset['subject_statuses'].apply(lambda x: mapping.get(x, 100))
# ```

# %%
dataset['subject_statuses'].value_counts()
# Out:
# Shoot and Miss          83
# Deceased                68
# Injured                 57
# 1 Deceased 1 Injured     2
# Deceased Injured         2
# Other                    1
# 2 Injured                1
# Name: subject_statuses, dtype: int64

# %%
mapping = {'Deceased': 1000, 'Injured': 500, 'Shoot and Miss': 250}
dataset['subject_statuses'] = dataset['subject_statuses'].apply(lambda x: mapping.get(x, 100))

# %% [markdown]
# ### Step 3.c: Visualize the data
# - Now we can visualize the data
# - This can be done with a scatter plot
# ```Python
# dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses', c='race', alpha=.5)
# ```
# - Where `s=` is the size feature and `c=` is the color feature, `figsize=` sets the size of the figure, `alpha=` sets the transparency of the dots.

# %%
dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses',c='race',alpha=0.25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4284             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4285                 colors = mcolors.to_rgba_array(c)
#    4286                 n_elem = colors.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     232             pass
# --> 233         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     234     # tuple color.
#
# ValueError: Invalid RGBA argument: 'a'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5405d2a2796a> in <module>
# ----> 1 dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses',c='race',alpha=0.25)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1442             ...                       colormap='viridis')
#    1443         """
# -> 1444         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1445
#    1446     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     279         self._compute_plot_data()
#     280         self._setup_subplots()
# --> 281         self._make_plot()
#     282         self._add_table()
#     283         self._make_legend()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#     967             label=label,
#     968             cmap=cmap,
# --> 969             **self.kwds
#     970         )
#     971         if cb:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4452             self._parse_scatter_color_args(
#    4453                 c, edgecolors, kwargs, xshape, yshape,
# -> 4454                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4455
#    4456         if plotnonfinite and colors is None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4304                         "'c' argument must be a mpl color, a sequence of mpl "
#    4305                         "colors or a sequence of numbers, not {}."
# -> 4306                             .format(c)  # note: could be long depending on c
#    4307                     )
#    4308         else:
#
# ValueError: 'c' argument must be a mpl color, a sequence of mpl colors or a sequence of numbers, not race.

# %% [markdown]
# ## Step 4: Report
# - Present findings
# - Visualize results
# - Credibility counts

# %% [markdown]
# ### Step 4.a: Present a chart
# - The goal here is to present your message
# - Visualize one chart
# - Add a headline (title) to give the audience a message

# %% [markdown]
# ### Step 4.b (Optional): Further improvements
# - Ideas to improve the visualization
# - Add description (legends) with color and size description.
# - Visualize it on a map
#     - You could use [folium](https://python-visualization.github.io/folium/)
#     - Explore [quick guide](https://python-visualization.github.io/folium/quickstart.html)

# %%
# ! sudo apt get install folium

# %%
import folium

# %%
m=folium.Map(location=[32.8,-96.8])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74d12a393524a2785de3d60e055e96a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74d12a393524a2785de3d60e055e96a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74d12a393524a2785de3d60e055e96a3 = L.map(
#                 &quot;map_74d12a393524a2785de3d60e055e96a3&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a30e08ae18335af8ce89e0f71a72133e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74d12a393524a2785de3d60e055e96a3);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in dataset.iterrows():
    folium.CircleMarker(
        location=[row['latitude'],row['longitude']],
        radius=row['subject_statuses']//100,
        popup="Laurelhurst Park",
        color=['race'],
        fill=True,
        fill_color=['race'],
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e34dbdbdb179bc35d02908774e57e20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e34dbdbdb179bc35d02908774e57e20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5e34dbdbdb179bc35d02908774e57e20 = L.map(
#                 &quot;map_5e34dbdbdb179bc35d02908774e57e20&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b99b3b8a4945b1d63abd44c12621128e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e34dbdbdb179bc35d02908774e57e20);
#
#
#             var circle_marker_d40b1cf0905abac4dc382fb535598b3d = L.circleMarker(
#                 [45.5215, -122.6261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e34dbdbdb179bc35d02908774e57e20);
#
#
#         var popup_3c3e9ef5469621d1ab36686f73844085 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_98727e2bc7ca50b37cc2b4a28cd27ada = $(`&lt;div id=&quot;html_98727e2bc7ca50b37cc2b4a28cd27ada&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#             popup_3c3e9ef5469621d1ab36686f73844085.setContent(html_98727e2bc7ca50b37cc2b4a28cd27ada);
#
#
#         circle_marker_d40b1cf0905abac4dc382fb535598b3d.bindPopup(popup_3c3e9ef5469621d1ab36686f73844085)
#         ;
#
#
#
#
#             var circle_marker_d193965c994956cdfeb53b0f9f6a2120 = L.circleMarker(
#                 [32.68642, -96.908674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: [&quot;race&quot;], &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: [&quot;race&quot;], &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e34dbdbdb179bc35d02908774e57e20);
#
#
#         var popup_3c07c31403f8c04ddba386bf91b9d5db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b5fc0a3c5ad128d2624fd51fee2b0aa3 = $(`&lt;div id=&quot;html_b5fc0a3c5ad128d2624fd51fee2b0aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#             popup_3c07c31403f8c04ddba386bf91b9d5db.setContent(html_b5fc0a3c5ad128d2624fd51fee2b0aa3);
#
#
#         circle_marker_d193965c994956cdfeb53b0f9f6a2120.bindPopup(popup_3c07c31403f8c04ddba386bf91b9d5db)
#         ;
#
#
#
#
#             var circle_marker_8f61cbb49d73aed37eb532571334cf51 = L.circleMarker(
#                 [32.864, -96.898998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: [&quot;race&quot;], &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: [&quot;race&quot;], &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e34dbdbdb179bc35d02908774e57e20);
#
#
#         var popup_c41a01deb0e2b7e901064784e365c9a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8a50a63ecb7c33403534c56242f9abca = $(`&lt;div id=&quot;html_8a50a63ecb7c33403534c56242f9abca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#             popup_c41a01deb0e2b7e901064784e365c9a5.setContent(html_8a50a63ecb7c33403534c56242f9abca);
#
#
#         circle_marker_8f61cbb49d73aed37eb532571334cf51.bindPopup(popup_c41a01deb0e2b7e901064784e365c9a5)
#         ;
#
#
#
#
#             var circle_marker_10a79d480d53b0a5a49dfa4b56bafe27 = L.circleMarker(
#                 [32.81482, -96.826787],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: [&quot;race&quot;], &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: [&quot;race&quot;], &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &qu

# %%
isb=folium.Map(location=[33.6844,73.0479])

# %%
isb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42f65e3f85e3eb2b907bec78386b233e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42f65e3f85e3eb2b907bec78386b233e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42f65e3f85e3eb2b907bec78386b233e = L.map(
#                 &quot;map_42f65e3f85e3eb2b907bec78386b233e&quot;,
#                 {
#                     center: [33.6844, 73.0479],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e2101f413a1f4e2300cf09a21e21fd8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42f65e3f85e3eb2b907bec78386b233e);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
